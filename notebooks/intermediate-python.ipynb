# %% [markdown]
# # Intermediate Python for Data Science
# ## Matplotlib
# - In python we have many visualization packages but the mother of all we can say is matplotlib.
# - We need it's subpackage pyplot

# %%
#visualizing evolution of world's population
import matplotlib.pyplot as plt 
year = [1950, 1970 , 1990, 2010]
population = [2.519, 3.692, 5.263, 6.972]
plt.plot(year, population)  # plt.plot(horizontal_axis, vertical_axis)  
plt.show()

# %% [markdown]
# - plot function tells python what to plot and how to plot whereas show displays the plot.
# ### Scatter Plot
# - It helps to simply plot all invidual data points and it helps to clearly show how many points the plot are based on.

# %%
plt.scatter(year, population)  # plt.scatter(horizontal_axis, vertical_axis)  
plt.show()

# %% [markdown]
# ### Exercise

# %%
# Sample data for months and sales
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
sales = [1200, 1500, 1800, 2100, 2500, 2300, 2700, 3000, 2800, 3200, 3500, 4000]

# Print the last item from months and sales
print(months[-1])  # Last month
print(sales[-1])   # Last month's sales

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Make a line plot: months on the x-axis, sales on the y-axis
plt.plot(months, sales)

# Display the plot
plt.show()
# Out:
# Dec
# 4000

# %%
import matplotlib.pyplot as plt

# Sample data: advertising budget (in $1000) vs sales revenue (in $1000)
ad_budget = [1, 5, 10, 50, 100, 500, 1000, 5000, 10000]  # Advertising budget
sales_revenue = [5, 20, 35, 80, 150, 400, 700, 3000, 6000]  # Corresponding sales revenue

# Create a scatter plot
plt.scatter(ad_budget, sales_revenue)

# Put the x-axis on a logarithmic scale
plt.xscale('log')

# Show plot
plt.show()

# %% [markdown]
# ## Histogram
# - A type of visualization useful for exploring dataset.
# - It helps to get idea about distribution of variables.
# ### Using matplotlib for histogram

# %%
import matplotlib.pyplot as plt
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x: 'ArrayLike | Sequence[ArrayLike]', bins: 'int | Sequence[float] | str | None' = None, range: 'tuple[float, float] | None' = None, density: 'bool' = False, weights: 'ArrayLike | None' = None, cumulative: 'bool | float' = False, bottom: 'ArrayLike | float | None' = None, histtype: "Literal['bar', 'barstacked', 'step', 'stepfilled']" = 'bar', align: "Literal['left', 'mid', 'right']" = 'mid', orientation: "Literal['vertical', 'horizontal']" = 'vertical', rwidth: 'float | None' = None, log: 'bool' = False, color: 'ColorType | Sequence[ColorType] | None' = None, label: 'str | Sequence[str] | None' = None, stacked: 'bool' = False, *, data=None, **kwargs) -> 'tuple[np.ndarray | list[np.ndarray], np.ndarray, BarContainer | Polygon | list[BarContainer | Polygon]]'
#     Compute and plot a histogram.
#
#     This method uses `numpy.histogram` to bin the data in *x* and count the
# ...

# %% [markdown]
# - x argument is the list of values that we want to build the histogram for and bins argument is used to tell for how many bins the data should be divided and by default it is 10.

# %%
values = [1, 1.1, 2.6, 3.5, 1.3, 0.5, 0.9, 1.9, 2.3, 3.2, 3.4, 2.1]
plt.hist(values, bins=3)
plt.show()

# %% [markdown]
# ### Exercise

# %%
import matplotlib.pyplot as plt
import numpy as np

# sample data distribution of exam scores
exam_scores = np.random.normal(75, 10, 1000)  # 1000 students scores with mean=75, std=10  --> follows normal distribution

# Create histogram of exam_scores data
plt.hist(exam_scores, bins=20, color='skyblue', edgecolor='black')

# Display histogram
plt.show()

# %%
# Build histogram with 5 bins
plt.hist(exam_scores, bins=5, color='skyblue', edgecolor='black')

# Show and clean up plot
plt.show()
plt.clf()    # cleans up the plot and start afresh

# Build histogram with 20 bins
plt.hist(exam_scores, bins=20, color='pink', edgecolor='black')

# Show and clean up again
plt.show()
plt.clf()

# %% [markdown]
# - Here we can see too many bins will overcomplicate the reality and hide the bigger picture.
# - plt.clf() helps to clear up the plot and start afresh.

# %% [markdown]
# ### Customization of plots
# - For each data visualization we have got many options:
#   - We have different plot types.
#   - For each plot we can deal with many customization such as changing colors, shape,size and so on.
#   - The choice of customization depends on data and the story we wanna tell.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Years from 1950 to 2100
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020, 2025, 2030, 
                  2040, 2050, 2060, 2070, 2080, 2100]

# Estimated and projected population (in billions)
population = [2.5, 3.0, 3.7, 4.4, 5.3, 6.1, 6.9, 7.8, 8.1, 8.5, 
                       9.1, 9.7, 10.0, 10.2, 10.4, 10.2]

years = [1800, 1850, 1900] + years
population = [1.0, 1.262, 1.650] + population

# Create the plot
plt.figure(figsize=(10, 5))
plt.plot(years, population, color='b', label='Population (Billions)')

# Adding titles and labels
plt.title('Global Population Growth (1950-2100)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.yticks([0, 2, 4, 6, 8, 10],               # this changes the y coordinate accordingly
           ['0', '2B', '4B', '6B', '8B', '10B'])

plt.legend()
plt.show()

# %% [markdown]
# ### Exercise
